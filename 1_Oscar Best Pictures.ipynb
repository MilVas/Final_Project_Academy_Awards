# %% [markdown]
# ## Oscar Awards Best Picture

# %%
#importing libraries
import pandas as pd
import numpy as np
import string
import re

# %%
# importing the dataset
oscar_df_1 = pd.read_excel('data/the_oscar_award_kaggle.xlsx')

# %%
# Inspecting DataFrame
oscar_df_1.head()
oscar_df_1.shape
oscar_df_1.dtypes
oscar_df_1.isna().sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               0
# film             304
# winner             0
# dtype: int64

# %%
# inspecting the missing values in film\n",
missing_films = oscar_df_1[oscar_df_1.isna().any(axis=1)]
missing_films['category'].value_counts()
#There are no missing values for the best picture category. At this point, there is no need to remove the rows with them.
# Out:
# HONORARY AWARD                          124
# SPECIAL AWARD                            56
# IRVING G. THALBERG MEMORIAL AWARD        45
# JEAN HERSHOLT HUMANITARIAN AWARD         39
# ASSISTANT DIRECTOR                       18
# SOUND RECORDING                           8
# HONORARY FOREIGN LANGUAGE FILM AWARD      5
# SPECIAL ACHIEVEMENT AWARD                 3
# ENGINEERING EFFECTS                       2
# SPECIAL FOREIGN LANGUAGE FILM AWARD       2
# WRITING (Title Writing)                   2
# Name: category, dtype: int64

# %%
oscar_df_1['category'].value_counts()
# Out:
# DIRECTING                                    449
# FILM EDITING                                 430
# ACTOR IN A SUPPORTING ROLE                   420
# ACTRESS IN A SUPPORTING ROLE                 420
# DOCUMENTARY (Short Subject)                  368
#                                             ...
# WRITING (Title Writing)                        3
# DIRECTING (Comedy Picture)                     2
# SPECIAL FOREIGN LANGUAGE FILM AWARD            2
# SPECIAL ACHIEVEMENT AWARD (Sound Editing)      1
# SPECIAL ACHIEVEMENT AWARD (Sound Effects)      1
# Name: category, Length: 111, dtype: int64

# %% [markdown]
# ## 2. Creating a dataframe with best picture category

# %%
#making a copy of the entire dataset
pictures = oscar_df_1.copy()

#creating categories for filtering
cats = ['OUTSTANDING PICTURE','OUTSTANDING PRODUCTION','OUTSTANDING MOTION PICTURE','BEST MOTION PICTURE','BEST PICTURE']

#selecting only movies that were nominated in the best picture category
pictures = pictures.loc[pictures['category'].isin(cats)]
pictures[pictures.isna().any(axis=1)]
# there are no missing values.
# Out:
# Empty DataFrame
# Columns: [year_film, year_ceremony, ceremony, category, name, film, winner]
# Index: []

# %%
pictures
# Out:
#        year_film  year_ceremony  ceremony             category  \
# 19          1928           1928         1  OUTSTANDING PICTURE
# 20          1927           1928         1  OUTSTANDING PICTURE
# 21          1927           1928         1  OUTSTANDING PICTURE
# 62          1929           1929         2  OUTSTANDING PICTURE
# 63          1928           1929         2  OUTSTANDING PICTURE
# ...          ...            ...       ...                  ...
# 10346       2019           2020        92         BEST PICTURE
# 10347       2019           2020        92         BEST PICTURE
# 10348       2019           2020        92         BEST PICTURE
# 10349       2019           2020        92         BEST PICTURE
# 10350       2019           2020        92         BEST PICTURE
#
#                                                     name  \
# 19                                     The Caddo Company
# 20                                                   Fox
# 21                                Paramount Famous Lasky
# 62                                   Feature Productions
# 63                                                   Fox
# ...                                                  ...
# 10346                               Amy Pascal, Producer
# 10347          Noah Baumbach and David Heyman, Producers
# 10348  Sam Mendes, Pippa Harris, Jayne-Ann Tenggren a...
# 10349  David Heyman, Shannon McIntosh and Quentin Tar...
# 10350            Kwak Sin Ae and Bong Joon Ho, Producers
#
#                                  film  winner
# 19                         The Racket   False
# 20                         7th Heaven   False
# 21                              Wings    True
# 62                              Alibi   False
# 63                     In Old Arizona   False
# ...                               ...     ...
# 10346                    Little Women   False
# 10347                  Marriage Story   False
# 10348                           1917;   False
# 10349  Once upon a Time… in Hollywood   False
# 10350                        Parasite    True
#
# [563 rows x 7 columns]

# %% [markdown]
# ## 3. Merging Oscar Data With IMDb Movies details

# %%
# Importing a csv file with over 80 000 movies and their details from IMDB
IMDB_movies = pd.read_excel('data/IMDB movies extensive dataset kaggle/IMDb_movies.xlsx')

# %%
# Inspecting the dataframe

IMDB_movies.shape
# 81273 movies , variables stored in 22 columns

IMDB_movies.head()
IMDB_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
# dropping unnecessary columns:


IMDB_movies=IMDB_movies.drop(columns = ['original_title','date_published','avg_vote','votes','budget','usa_gross_income',
                                         'worlwide_gross_income', 'metascore','reviews_from_users', 'reviews_from_critics'])

# %%
IMDB_movies.head()
IMDB_movies.shape
# Out:
# (81273, 12)

# %%
#make titles in both dataframes upper-case, to minimize the possible errors caused by different capitalization.
IMDB_movies['title'] = IMDB_movies['title'].str.upper()
pictures['film'] = pictures['film'].str.upper()

#making sure there is a blank space after a comma in names of movies
IMDB_movies['title'] = IMDB_movies['title'].str.replace(',',', ')
pictures['film'] = pictures['film'].str.replace(',',', ')

#Stripping potential blank spaces
IMDB_movies['title'] = IMDB_movies['title'].str.strip()
pictures['film'] = pictures['film'].str.strip()

# %% [markdown]
# Most of types look alright.This table will be merged with the pictures table on a left join- so that only the information for the selected oscar films is added

# %%
pictures_combined = pd.merge(pictures, IMDB_movies, how='left', left_on=['film', 'year_film'], right_on=['title','year'])

# %%
pictures_combined.loc[pictures_combined.film=='LITTLE WOMEN']
# This film from 2019 is wrong in the imdb kaggle dataset. the oscar nominee was Greta Gedwig`s film. it will be manually changed below.
# Out:
#      year_film  year_ceremony  ceremony                category  \
# 31        1933           1933         6  OUTSTANDING PRODUCTION
# 558       2019           2020        92            BEST PICTURE
#
#                      name          film  winner imdb_title_id         title  \
# 31              RKO Radio  LITTLE WOMEN   False     tt0024264  LITTLE WOMEN
# 558  Amy Pascal, Producer  LITTLE WOMEN   False     tt6495094  LITTLE WOMEN
#
#        year                   genre  duration country         language  \
# 31   1933.0  Drama, Family, Romance     115.0     USA  English, German
# 558  2019.0           Drama, Family     112.0     USA          English
#
#               director                                writer  \
# 31        George Cukor     Louisa May Alcott, Sarah Y. Mason
# 558  Clare Niederpruem  Louisa May Alcott, Clare Niederpruem
#
#        production_company                                             actors  \
# 31     RKO Radio Pictures  Katharine Hepburn, Joan Bennett, Paul Lukas, E...
# 558  Main Dog Productions  Sarah Davenport, Lea Thompson, Allie Jennings,...
#
#                                            description
# 31   A chronicle of the lives of a group of sisters...
# 558  A modern retelling of Louisa May Alcott's clas...

# %%
# changing little women info

pictures_combined.at[558,'imdb_title_id'] = 'tt3281548'
pictures_combined.at[558,'director'] = 'Greta Gedwig'
pictures_combined.at[558,'actors'] = "'Saoirse Ronan', 'Emma Watson', 'Florence Pugh', 'Eliza Scanlen','Laura Dern','Meryl Streep'"
pictures_combined.at[558,'director'] = 'Greta Gerwig'
pictures_combined.at[558,'genre'] = "'Drama','Romance'"
pictures_combined.at[558,'duration'] = 135

# %%
pictures_combined[pictures_combined['title'].isnull()]
# Out:
#      year_film  year_ceremony  ceremony                category  \
# 7         1928           1929         2     OUTSTANDING PICTURE
# 14        1931           1931         4  OUTSTANDING PRODUCTION
# 47        1934           1935         7  OUTSTANDING PRODUCTION
# 560       2019           2020        92            BEST PICTURE
# 561       2019           2020        92            BEST PICTURE
# 562       2019           2020        92            BEST PICTURE
#
#                                                   name  \
# 7                               Paramount Famous Lasky
# 14                                                 Fox
# 47                 Jesse L. Lasky (production company)
# 560  Sam Mendes, Pippa Harris, Jayne-Ann Tenggren a...
# 561  David Heyman, Shannon McIntosh and Quentin Tar...
# 562            Kwak Sin Ae and Bong Joon Ho, Producers
#
#                                film  winner imdb_title_id title  year genre  \
# 7                       THE PATRIOT   False           NaN   NaN   NaN   NaN
# 14                       EAST LYNNE   False           NaN   NaN   NaN   NaN
# 47                 THE WHITE PARADE   False           NaN   NaN   NaN   NaN
# 560                           1917;   False           NaN   NaN   NaN   NaN
# 561  ONCE UPON A TIME… IN HOLLYWOOD   False           NaN   NaN   NaN   NaN
# 562                        PARASITE    True           NaN   NaN   NaN   NaN
#
#      duration country language director writer production_company actors  \
# 7         NaN     NaN      NaN      NaN    NaN                NaN    NaN
# 14        NaN     NaN      NaN      NaN    NaN                NaN    NaN
# 47        NaN     NaN      NaN      NaN    NaN                NaN    NaN
# 560       NaN     NaN      NaN      NaN    NaN                NaN    NaN
# 561       NaN     NaN      NaN      NaN    NaN                NaN    NaN
# 562       NaN     NaN      NaN      NaN    NaN                NaN    NaN
#
#     description
# 7           NaN
# 14          NaN
# 47          NaN
# 560         NaN
# 561         NaN
# 562         NaN

# %%
# 6 films were not successfully merged(they were missing in the IMDB dataset). the Main infromation will be added manually:
pictures_combined.at[7,'imdb_title_id'] = 'tt0019257'
pictures_combined.at[7,'genre'] = 'Drama, History, Thriller'
pictures_combined.at[7,'director'] = 'Ernst Lubitsch'
pictures_combined.at[7,'duration'] = 113


pictures_combined.at[14,'imdb_title_id'] = 'tt0021826'
pictures_combined.at[14,'genre'] = 'Drama, Romance'
pictures_combined.at[14,'director'] = 'Frank Lloyd'
pictures_combined.at[14,'duration'] = 102


pictures_combined.at[47,'imdb_title_id'] = 'tt0025986'
pictures_combined.at[47,'genre'] = 'Drama'
pictures_combined.at[47,'director'] = 'Irving Cummings'
pictures_combined.at[47,'duration'] = 80


pictures_combined.at[560,'imdb_title_id'] = 'tt8579674'
pictures_combined.at[560,'genre'] = 'Drama, War'
pictures_combined.at[560,'director'] = 'Sam Mendes'
pictures_combined.at[560,'duration'] = 119

pictures_combined.at[561,'imdb_title_id'] = 'tt7131622'
pictures_combined.at[561,'genre'] = 'Comedy,Drama'
pictures_combined.at[561,'director'] = 'Quentin Tarantino'
pictures_combined.at[561,'duration'] = 161

pictures_combined.at[562,'imdb_title_id'] = 'tt6751668'
pictures_combined.at[562,'genre'] = 'Comedy,Drama, Thriller'
pictures_combined.at[562,'director'] = 'Bong Joon Ho'
pictures_combined.at[562,'duration'] = 132

# %%
# Some movies have two directors. Splitting their names in two columns for later checking
pictures_combined[['first_director','second_director']] = pictures_combined.director.str.split(',', expand = True)

# %%
# Out:
#    year_film  year_ceremony  ceremony             category  \
# 0       1928           1928         1  OUTSTANDING PICTURE
# 1       1927           1928         1  OUTSTANDING PICTURE
# 2       1927           1928         1  OUTSTANDING PICTURE
# 3       1929           1929         2  OUTSTANDING PICTURE
# 4       1928           1929         2  OUTSTANDING PICTURE
#
#                      name            film  winner imdb_title_id  \
# 0       The Caddo Company      THE RACKET   False     tt0019304
# 1                     Fox      7TH HEAVEN   False     tt0018379
# 2  Paramount Famous Lasky           WINGS    True     tt0018578
# 3     Feature Productions           ALIBI   False     tt0019630
# 4                     Fox  IN OLD ARIZONA   False     tt0020018
#
#             title    year  ... duration  country                   language  \
# 0      THE RACKET  1928.0  ...     84.0      USA                    English
# 1      7TH HEAVEN  1927.0  ...    110.0      USA                    English
# 2           WINGS  1927.0  ...    144.0      USA                    English
# 3           ALIBI  1929.0  ...     91.0      USA                    English
# 4  IN OLD ARIZONA  1928.0  ...     95.0      USA  English, Spanish, Italian
#
#                                        director  \
# 0                               Lewis Milestone
# 1                                 Frank Borzage
# 2  William A. Wellman, Harry d'Abbadie d'Arrast
# 3                                   Roland West
# 4                               Irving Cummings
#
#                                writer                  production_company  \
# 0  Bartlett Cormack, Bartlett Cormack                   The Caddo Company
# 1      Austin Strong, Benjamin Glazer            Frank Borzage Production
# 2     John Monk Saunders, Hope Loring  Paramount Famous Lasky Corporation
# 3    Roland West, C. Gardner Sullivan                 Feature Productions
# 4                 O. Henry, Tom Barry                Fox Film Corporation
#
#                                               actors  \
# 0  Thomas Meighan, Louis Wolheim, Marie Prevost, ...
# 1  Janet Gaynor, Charles Farrell, Albert Gran, Da...
# 2  Clara Bow, Charles 'Buddy' Rogers, Richard Arl...
# 3  Chester Morris, Harry Stubbs, Mae Busch, Elean...
# 4        Warner Baxter, Edmund Lowe, Dorothy Burgess
#
#                                          description      first_director  \
# 0  An honest police captain vows to bring down a ...     Lewis Milestone
# 1  A street cleaner saves a young woman's life, a...       Frank Borzage
# 2  Two young men, one rich, one middle class, who...  William A. Wellman
# 3  Chick Williams, a prohibition gangster, rejoin...         Roland West
# 4  A charming, happy-go-lucky bandit in old Arizo...     Irving Cummings
#
#              second_director
# 0                       None
# 1                       None
# 2   Harry d'Abbadie d'Arrast
# 3                       None
# 4                       None
#
# [5 rows x 21 columns]

# %%
pictures_combined.to_csv('data/pictures_combined.csv',index=False)
